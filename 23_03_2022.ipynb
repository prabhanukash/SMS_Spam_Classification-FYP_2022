# %%
import pandas as pd
import numpy as np
from collections import Counter
from keras.preprocessing.text import text_to_word_sequence

# %%
pip install indic-nlp-library
# Out:
# ...
#      |████████████████████████████████| 40 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 8.4 MB/s
# ...

# %%
data1 = pd.read_csv('/content/spam.csv', encoding = 'latin-1') # Kaggle dataset
data1 = data1.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis = 1)
print("Kaggle dataset head:")
data1.head()
# Out:
# Kaggle dataset head:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data=pd.read_excel('/content/Final_Dataset.xlsx')
data.head
# Out:
# <bound method NDFrame.head of       code ham/spam                                            message  \
# 0        1      ham  004645 is SECRET OTP for txn of INR 11893.00 o...
# 1        1      ham  133355 is your OTP for conﬁrmation. Regards AP...
# 2        1      ham  223316 is your OTP for conﬁrmation. Regards AP...
# 3        1      ham  237222 is your OTP for conﬁrmation. Regards AP...
# 4        1      ham  269220 is SECRET OTP for txn of INR 11893.00 o...
# ...    ...      ...                                                ...
# 3888     1     spam  Dear Member, Shop for WROGN worth Rs6999 & GET...
# 3889     1     spam  Lenskart Mega Sale: Get 40% Off plus Buy1Get1 ...
# 3890     1     spam  Bodapatiabhiteja, get EXTRA Rs.300 Off today\n...
# 3891     1     spam  Dear Customer,TRENDS SPECIAL OFFER! Get Rs500 ...
# 3892     1     spam  UPTO 50% OFF @TRENDS End Of Season Sale!!! Sho...
#
#      Unnamed: 3
# 0           NaN
# 1           NaN
# 2           NaN
# ...

# %%
list = ['Unnamed: 3']
data = data.drop(list, axis=1)

# %%
data.head
# Out:
# <bound method NDFrame.head of       code ham/spam                                            message
# 0        1      ham  004645 is SECRET OTP for txn of INR 11893.00 o...
# 1        1      ham  133355 is your OTP for conﬁrmation. Regards AP...
# 2        1      ham  223316 is your OTP for conﬁrmation. Regards AP...
# 3        1      ham  237222 is your OTP for conﬁrmation. Regards AP...
# 4        1      ham  269220 is SECRET OTP for txn of INR 11893.00 o...
# ...    ...      ...                                                ...
# 3888     1     spam  Dear Member, Shop for WROGN worth Rs6999 & GET...
# 3889     1     spam  Lenskart Mega Sale: Get 40% Off plus Buy1Get1 ...
# 3890     1     spam  Bodapatiabhiteja, get EXTRA Rs.300 Off today\n...
# 3891     1     spam  Dear Customer,TRENDS SPECIAL OFFER! Get Rs500 ...
# 3892     1     spam  UPTO 50% OFF @TRENDS End Of Season Sale!!! Sho...
#
# [3893 rows x 3 columns]>

# %%
data.dropna()
# Out:
#       code ham/spam                                            message
# 0        1      ham  004645 is SECRET OTP for txn of INR 11893.00 o...
# 1        1      ham  133355 is your OTP for conﬁrmation. Regards AP...
# 2        1      ham  223316 is your OTP for conﬁrmation. Regards AP...
# 3        1      ham  237222 is your OTP for conﬁrmation. Regards AP...
# 4        1      ham  269220 is SECRET OTP for txn of INR 11893.00 o...
# ...    ...      ...                                                ...
# 3888     1     spam  Dear Member, Shop for WROGN worth Rs6999 & GET...
# 3889     1     spam  Lenskart Mega Sale: Get 40% Off plus Buy1Get1 ...
# 3890     1     spam  Bodapatiabhiteja, get EXTRA Rs.300 Off today\n...
# 3891     1     spam  Dear Customer,TRENDS SPECIAL OFFER! Get Rs500 ...
# 3892     1     spam  UPTO 50% OFF @TRENDS End Of Season Sale!!! Sho...
#
# [3893 rows x 3 columns]

# %%
data['code'] = data['code'].astype("Int64")

# %%
data.shape
# Out:
# (3893, 3)

# %% [markdown]
# **For English**

# %%
lst = []
i = 0
for row in data.itertuples():
  if not row[1] == 1:
    lst.append(i)
    i = i + 1

# %%
data_eng = data.drop(data.index[lst], axis = 0)

# %%
data_eng.shape
# Out:
# (3268, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data1['v2'], data1['v1'], test_size = 0.30)

Y_train = pd.get_dummies(Y_train).values

# %%
X_test.head
# Out:
# <bound method NDFrame.head of 2425    Hey!!! I almost forgot ... Happy B-day babe ! ...
# 3620    That means from february to april i'll be gett...
# 4107                        Pls send me your address sir.
# 1640            Alright, we're all set here, text the man
# 441                You were supposed to wake ME up &gt;:(
#                               ...
# 3182    Dunno i juz askin cos i got a card got 20% off...
# 1652    For ur chance to win a å£250 cash every wk TXT...
# 2637    No I don't have cancer. Moms making a big deal...
# 2816    Gr8 Poly tones 4 ALL mobs direct 2u rply with ...
# 2835                         Nice.nice.how is it working?
# Name: v2, Length: 1672, dtype: object>

# %%
from keras.preprocessing.text import text_to_word_sequence
temp = []
for i in range(len(X_train)):
    words = []
    rev = str(X_train.iloc[i])
    rev = text_to_word_sequence(rev)
    temp.append(rev)
X_train = temp

# %%
X_train
# Out:
# [['ur',
#   'balance',
#   'is',
#   'now',
#   'å£500',
#   'ur',
#   'next',
#   'question',
#   'is',
#   'who',
#   'sang',
#   "'uptown",
#   "girl'",
#   'in',
#   'the',
#   "80's",
#   '2',
#   'answer',
#   'txt',
#   'ur',
#   'answer',
#   'to',
#   '83600',
#   'good',
#   'luck'],
#  ['just',
#   'got',
#   'some',
#   'gas',
#   'money',
#   'any',
#   'chance',
#   'you',
#   'and',
#   'the',
#   'gang',
#   'want',
#   'to',
#   'go',
#   'on',
#   'a',
#   'grand',
#   'nature',
#   'adventure'],
#  ['thats',
#   'cool',
#   'i',
#   'am',
#   'a',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['ìï', 'takin', 'linear', 'algebra', 'today'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   '500',
#   'pounds',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   '86688',
#   'only',
#   '150p',
#   'msg',
#   'cc',
# ...

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

max_features = 3000

tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(X_train)

# %%
X_train
# Out:
# array([[   0,    0,    0, ..., 2337,   56,  841],
#        [   0,    0,    0, ...,    4, 1809, 1502],
#        [   0,    0,    0, ..., 1811,    7, 1301],
#        ...,
#        [   0,    0,    0, ...,    4,  234,   66],
#        [   0,    0,    0, ...,   40,  379,  525],
#        [   0,    0,    0, ...,  114, 2293, 1799]], dtype=int32)

# %% [markdown]
# **For Hindi**

# %%
lst = []
i = 0
for row in data.itertuples():
    if not row[1] == 2:
        lst.append(i)
    i = i + 1

# %%
data_hin = data.drop(data.index[lst], axis = 0)

# %%
data_hin.shape
# Out:
# (100, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data_hin['message'], data_hin['ham/spam'], test_size = 0.30)

Y_train = pd.get_dummies(Y_train).values

# %%
from keras.preprocessing.text import text_to_word_sequence
temp = []
for i in range(len(X_train)):
    words = []
    rev = str(X_train.iloc[i])
    rev = text_to_word_sequence(rev)
    temp.append(rev)
X_train = temp

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

max_features = 600

tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(X_train)

# %% [markdown]
# **For Telugu**

# %%
lst = []
i = 0
for row in data.itertuples():
    if not row[1] == 4:
        lst.append(i)
    i = i + 1

# %%
data_tel = data.drop(data.index[lst], axis = 0)

# %%
data_tel.shape
# Out:
# (392, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data_hin['message'], data_hin['ham/spam'], test_size = 0.30)

Y_train = pd.get_dummies(Y_train).values

# %%
from keras.preprocessing.text import text_to_word_sequence
temp = []
for i in range(len(X_train)):
    words = []
    rev = str(X_train.iloc[i])
    rev = text_to_word_sequence(rev)
    temp.append(rev)
X_train = temp

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

max_features = 600

tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(X_train)
